# %%
import pandas as pd
import datetime
from datetime import datetime
import numpy as np
#from sklearn.metrics import balanced_accuracy_score
#from sklearn.metrics import confusion_matrix
#from imblearn.metrics import classification_report_imbalanced
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.preprocessing import StandardScaler
#from sklearn.model_selection import train_test_split

# %%
data_df=pd.read_csv('Recruitment_pipeline_coded.csv')
# Out:
# C:\Users\ledwa\AppData\Local\Temp\ipykernel_51072\2042880330.py:1: DtypeWarning: Columns (26,27,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df=pd.read_csv('Recruitment_pipeline_coded.csv')

# %%
data_df=data_df.drop(labels=['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'], axis = 1)
#data_df.dropna(axis=0)
data_df.sort_values('study_id')
# Out:
#                                study_id  sex  birthyear initial_date  \
# 80873  000072707dfec2c31fc32b41f30f361e  2.0     2002.0    3/10/2022
# 56027  00009f6fca68b07d0bcd8510ebafb5c7  2.0     1995.0     4/8/2021
# 58583  00017d1b0b2d63ec9d6b716cb06e9786  2.0     1990.0    6/30/2021
# 406    0001839fdd549c14997582a3c15c192b  2.0     1992.0    9/27/2018
# 54224  0001b470ffdea9daf4e3e25a9cfb93d0  NaN        NaN          NaN
# ...                                 ...  ...        ...          ...
# 70844  fffea6ce95fc09eaabab4ed45c13b97e  1.0     1971.0    2/22/2022
# 53896  ffff49a8692e072fcb5df471ac7bd82a  NaN        NaN          NaN
# 53895  ffff49a8692e072fcb5df471ac7bd82a  2.0     1972.0     3/3/2021
# 52348  ffffc62548887f3f08ef51baf4a4e9ef  2.0     1980.0    3/15/2021
# 33460  ffffd2abbe994351375d62b864150a13  1.0     1993.0     2/3/2020
#
#       initial_contact_method          fu_dt_1      fu_method_1 fu_outcome_1  \
# 80873                  email              NaN              NaN          NaN
# 56027                  email  4/16/2021 16:00               vm          NaN
# 58583                  email              NaN              NaN          NaN
# 406                    email  10/8/2018 16:46  unable_to_reach          NaN
# 54224                    NaN              NaN              NaN          NaN
# ...                      ...              ...              ...          ...
# 70844                  email              NaN              NaN          NaN
# 53896                    NaN              NaN              NaN          NaN
# 53895                  email   3/5/2021 15:26            phone          NaN
# 52348                  email  3/29/2021 15:51            phone          NaN
# 33460                  email   2/5/2020 10:12            phone          NaN
#
#                 fu_dt_2 fu_method_2  ... fu_outcome_4 fu_dt_5 fu_method_5  \
# 80873               NaN         NaN  ...          NaN     NaN         NaN
# 56027               NaN         NaN  ...          NaN     NaN         NaN
# 58583               NaN         NaN  ...          NaN     NaN         NaN
# 406    10/17/2018 11:02       phone  ...          NaN     NaN         NaN
# 54224               NaN         NaN  ...          NaN     NaN         NaN
# ...                 ...         ...  ...          ...     ...         ...
# 70844               NaN         NaN  ...          NaN     NaN         NaN
# 53896               NaN         NaN  ...          NaN     NaN         NaN
# 53895    3/4/2022 14:49          vm  ...          NaN     NaN         NaN
# 52348               NaN         NaN  ...          NaN     NaN         NaN
# 33460               NaN         NaN  ...          NaN     NaN         NaN
#
#       fu_outcome_5 visit_planned_date visit_reminder_date actual_visit_date  \
# 80873          NaN                NaN                 NaN               NaN
# 56027          NaN                NaN                 NaN               NaN
# 58583          NaN                NaN                 NaN               NaN
# 406            NaN                NaN                 NaN               NaN
# 54224          NaN           3/9/2021                 NaN         3/15/2021
# ...            ...                ...                 ...               ...
# 70844          NaN                NaN                 NaN               NaN
# 53896          NaN           3/5/2021           3/18/2021         3/19/2021
# 53895          NaN                NaN                 NaN               NaN
# 52348          NaN                NaN                 NaN               NaN
# 33460          NaN                NaN                 NaN               NaN
#
#       visit_weekday coded_location        visit_outcome
# 80873           NaN            NaN                  NaN
# 56027           NaN            NaN                  NaN
# 58583           NaN            NaN                  NaN
# 406             NaN            NaN                  NaN
# 54224             M            7.0  reschedule_me_later
# ...             ...            ...                  ...
# 70844           NaN            NaN                  NaN
# 53896             F            2.0  reschedule_me_later
# 53895           NaN            NaN                  NaN
# 52348           NaN            NaN                  NaN
# 33460           NaN            NaN                  NaN
#
# [108719 rows x 26 columns]

# %%
#data_df=data_df[data_df['sex'].notna()]
#data_df=data_df[data_df['initial_contact_method'].notna()]
#data_df=data_df[data_df['visit_outcome'].notna()]
#data_df=data_df[data_df['study_id']].drop_duplicates()
#data_df=data_df.set_index('study_id')
#df=data_df.groupby(by=['study_id'], axis=1, as_index='True')
#data_df
#data_df.to_csv('test.csv')
#data_df['study_id'].value_counts()

### calculating the number of times that the participant was schedualed to show up
data_df['freq']=data_df.groupby('study_id')['study_id'].transform('count') - 1

### condesing all rows that are duplicates on the study_id into one. WARNING this is not perfect and we are losing some data in the visit_planned_date through the visit_outcome data. Right now it just picks either the first or last data that came up in those columns when combinding them
condensed_data=data_df.groupby(data_df['study_id']).aggregate({'study_id': 'first', 'sex': 'first', 'birthyear': 'first', 'initial_date': 'first', 'initial_contact_method': 'first', 'fu_dt_1':  'first', 'fu_method_1': 'first', 'fu_outcome_1': 'first', 'fu_dt_2': 'first'
,'fu_method_2': 'first', 'fu_outcome_2': 'first', 'fu_dt_3':'first', 'fu_method_3': 'first', 'fu_outcome_3': 'first', 'fu_dt_4':'first', 'fu_method_4': 'first', 'fu_outcome_4': 'first',  'fu_dt_5':'first', 'fu_method_5': 'first', 'fu_outcome_5': 'first', 'visit_planned_date': 'last'
, 'visit_reminder_date': 'last', 'actual_visit_date':'last', 'visit_weekday':'last', 'coded_location':'last', 'visit_outcome':'last', 'freq':'first'})

### droping data where visit outcome is na
condensed_data=condensed_data[condensed_data['visit_outcome'].notna()]

### making a data frame of just the contact attempts before the appointment
count_stuff=condensed_data[['fu_dt_1','fu_dt_2', 'fu_dt_3', 'fu_dt_4', 'fu_dt_5']]

### calculating the number of attempts made to contact the participant
condensed_data['contact_count']= 5- count_stuff.isnull().sum(axis=1)

### converting the birth year to a date
condensed_data['birthyear']=pd.to_datetime(condensed_data['birthyear'], format='%Y', exact=False)

### converting the actual_visit_date to a date
condensed_data['actual_visit_date']=pd.to_datetime(condensed_data['actual_visit_date'], format='%m/%d/%Y', exact=False)
condensed_data['initial_date']=pd.to_datetime(condensed_data['initial_date'], format='%m/%d/%Y', exact=False)

### Calculating the age of the person at the time of their visit.... its stuck in days and not years right now :/
#condensed_data['Age_at_visit']=(condensed_data['actual_visit_date']- condensed_data['birthyear'])

condensed_data['birthyear'] = condensed_data.birthyear.dt.year


#condensed_data.age = condensed_data.age.fillna(-1)
condensed_data['time_of_visit_from_planned']= condensed_data['actual_visit_date'] - condensed_data['initial_date']

# condensed_data['new_age'] = condensed_data['age'].apply(np.int64)

condensed_data['year'] = condensed_data.actual_visit_date.dt.year
condensed_data['age']= condensed_data['year'] - condensed_data['birthyear']
# condensed_data['time_fu_dt_2'] = condensed_data['fu_dt_2'].time()

#condensed_data['new_age'] = condensed_data['age'].apply(np.int64)

#condensed_data["date_time_fu_dt_2"] = pd.to_datetime(condensed_data["fu_dt_2"])

#for d in condensed_data['date_time_fu_dt_2']:
 # condensed_data['date_fu_dt_2'] = d.date()
  #condensed_data['time_fu_dt_2'] = d.time()

#condensed_data['date_fu_dt_2'] = pd.to_datetime(condensed_data['date_time_fu_dt_2']).dt.date
#condensed_data['time_fu_dt_2'] = pd.to_datetime(condensed_data['date_time_fu_dt_2']).dt.time

condensed_data['age'] = condensed_data['age'].astype('Int16')
condensed_data
# Out:
#                                                           study_id  sex  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0  0001b470ffdea9daf4e3e25a9cfb93d0  2.0
# 0003a8af34dd38929b6d0dff83a281e5  0003a8af34dd38929b6d0dff83a281e5  NaN
# 00042cd8cfa979e5cbf9aa79a01ec23d  00042cd8cfa979e5cbf9aa79a01ec23d  2.0
# 0014065de00658be8463cc209aae5bc1  0014065de00658be8463cc209aae5bc1  2.0
# 001e2c5b018d498cd8498e2b9d0ce0c7  001e2c5b018d498cd8498e2b9d0ce0c7  2.0
# ...                                                            ...  ...
# ffec65b7a5fd2d36cd56e0b249322d1f  ffec65b7a5fd2d36cd56e0b249322d1f  NaN
# ffeeb12c35a69dcdd34c4b2db6951789  ffeeb12c35a69dcdd34c4b2db6951789  2.0
# ffef6be3cbb0c80342dba653133169df  ffef6be3cbb0c80342dba653133169df  1.0
# fffdb5ffd34614801b0eb102ad4527bd  fffdb5ffd34614801b0eb102ad4527bd  1.0
# ffff49a8692e072fcb5df471ac7bd82a  ffff49a8692e072fcb5df471ac7bd82a  2.0
#
#                                   birthyear initial_date  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0     1980.0   2021-02-28
# 0003a8af34dd38929b6d0dff83a281e5        NaN   2019-10-16
# 00042cd8cfa979e5cbf9aa79a01ec23d     1947.0   2021-06-30
# 0014065de00658be8463cc209aae5bc1     1961.0   2020-01-17
# 001e2c5b018d498cd8498e2b9d0ce0c7     1958.0   2020-03-13
# ...                                     ...          ...
# ffec65b7a5fd2d36cd56e0b249322d1f     1970.0   2020-01-13
# ffeeb12c35a69dcdd34c4b2db6951789     1955.0   2019-09-22
# ffef6be3cbb0c80342dba653133169df     1933.0   2019-09-28
# fffdb5ffd34614801b0eb102ad4527bd     1981.0   2019-04-20
# ffff49a8692e072fcb5df471ac7bd82a     1972.0   2021-03-03
#
#                                  initial_contact_method           fu_dt_1  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0                  email    3/9/2021 15:26
# 0003a8af34dd38929b6d0dff83a281e5          self_referred  10/16/2019 15:11
# 00042cd8cfa979e5cbf9aa79a01ec23d                  email    7/8/2021 12:40
# 0014065de00658be8463cc209aae5bc1                  email   1/21/2020 17:50
# 001e2c5b018d498cd8498e2b9d0ce0c7                  email              None
# ...                                                 ...               ...
# ffec65b7a5fd2d36cd56e0b249322d1f              in_person    1/13/2020 9:54
# ffeeb12c35a69dcdd34c4b2db6951789                  email  10/21/2019 15:31
# ffef6be3cbb0c80342dba653133169df                  email              None
# fffdb5ffd34614801b0eb102ad4527bd                  email    4/26/2019 9:00
# ffff49a8692e072fcb5df471ac7bd82a                  email    3/5/2021 15:26
#
#                                  fu_method_1  fu_outcome_1           fu_dt_2  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0       phone          None    4/8/2022 14:38
# 0003a8af34dd38929b6d0dff83a281e5       phone          None              None
# 00042cd8cfa979e5cbf9aa79a01ec23d       phone  crc_followup    4/8/2022 12:25
# 0014065de00658be8463cc209aae5bc1       phone          None   2/24/2022 17:13
# 001e2c5b018d498cd8498e2b9d0ce0c7        None          None              None
# ...                                      ...           ...               ...
# ffec65b7a5fd2d36cd56e0b249322d1f       phone          None              None
# ffeeb12c35a69dcdd34c4b2db6951789          vm          None  10/23/2019 13:34
# ffef6be3cbb0c80342dba653133169df        None          None              None
# fffdb5ffd34614801b0eb102ad4527bd       phone          None              None
# ffff49a8692e072fcb5df471ac7bd82a       phone          None    3/4/2022 14:49
#
#                                  fu_method_2  ... visit_reminder_date  \
# study_id                                      ...
# 0001b470ffdea9daf4e3e25a9cfb93d0       phone  ...           4/20/2022
# 0003a8af34dd38929b6d0dff83a281e5        None  ...          10/21/2019
# 00042cd8cfa979e5cbf9aa79a01ec23d       phone  ...           4/27/2022
# 0014065de00658be8463cc209aae5bc1       phone  ...           3/21/2022
# 001e2c5b018d498cd8498e2b9d0ce0c7        None  ...           7/29/2022
# ...                                      ...  ...                 ...
# ffec65b7a5fd2d36cd56e0b249322d1f        None  ...           1/28/2020
# ffeeb12c35a69dcdd34c4b2db6951789       phone  ...          11/14/2019
# ffef6be3cbb0c80342dba653133169df        None  ...           10/7/2019
# fffdb5ffd34614801b0eb102ad4527bd        None  ...           4/30/2019
# ffff49a8692e072fcb5df471ac7bd82a          vm  ...           3/18/2021
#
#                                  actual_visit_date visit_weekday  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0        2022-04-21             R
# 0003a8af34dd38929b6d0dff83a281e5        2019-10-22             T
# 00042cd8cfa979e5cbf9aa79a01ec23d        2022-04-28             R
# 0014065de00658be8463cc209aae5bc1        2022-03-23             W
# 001e2c5b018d498cd8498e2b9d0ce0c7        2022-12-05             M
# ...                                            ...           ...
# ffec65b7a5fd2d36cd56e0b249322d1f        2020-01-29             W
# ffeeb12c35a69dcdd34c4b2db6951789        2019-11-15             F
# ffef6be3cbb0c80342dba653133169df        2019-10-08             T
# fffdb5ffd34614801b0eb102ad4527bd        2019-05-01             W
# ffff49a8692e072fcb5df471ac7bd82a        2021-03-19             F
#
#                                  coded_location        visit_outcome freq  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0            1.0              no_show    2
# 0003a8af34dd38929b6d0dff83a281e5            2.0            completed    1
# 00042cd8cfa979e5cbf9aa79a01ec23d            1.0              no_show    3
# 0014065de00658be8463cc209aae5bc1            7.0             canceled    3
# 001e2c5b018d498cd8498e2b9d0ce0c7            2.0          rescheduled    2
# ...                                         ...                  ...  ...
# ffec65b7a5fd2d36cd56e0b249322d1f            2.0            completed    1
# ffeeb12c35a69dcdd34c4b2db6951789            5.0  reschedule_me_later    1
# ffef6be3cbb0c80342dba653133169df            7.0             canceled    1
# fffdb5ffd34614801b0eb102ad4527bd            2.0            completed    1
# ffff49a8692e072fcb5df471ac7bd82a            2.0  reschedule_me_later    1
#
#                                  contact_count time_of_visit_from_planned  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0             5                   417 days
# 0003a8af34dd38929b6d0dff83a281e5             1                     6 days
# 00042cd8cfa979e5cbf9aa79a01ec23d             4                   302 days
# 0014065de00658be8463cc209aae5bc1             5                   796 days
# 001e2c5b018d498cd8498e2b9d0ce0c7             0                   997 days
# ...                                        ...                        ...
# ffec65b7a5fd2d36cd56e0b249322d1f             1                    16 days
# ffeeb12c35a69dcdd34c4b2db6951789             3                    54 days
# ffef6be3cbb0c80342dba653133169df             0                    10 days
# fffdb5ffd34614801b0eb102ad4527bd             1                    11 days
# ffff49a8692e072fcb5df471ac7bd82a             3                    16 days
#
#                                   year   age
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0  2022    42
# 0003a8af34dd38929b6d0dff83a281e5  2019  <NA>
# 00042cd8cfa979e5cbf9aa79a01ec23d  2022    75
# 0014065de00658be8463cc209aae5bc1  2022    61
# 001e2c5b018d498cd8498e2b9d0ce0c7  2022    64
# ...                                ...   ...
# ffec65b7a5fd2d36cd56e0b249322d1f  2020    50
# ffeeb12c35a69dcdd34c4b2db6951789  2019    64
# ffef6be3cbb0c80342dba653133169df  2019    86
# fffdb5ffd34614801b0eb102ad4527bd  2019    38
# ffff49a8692e072fcb5df471ac7bd82a  2021    49
#
# [9150 rows x 31 columns]

# %%
count_stuff=condensed_data[['fu_dt_1','fu_dt_2', 'fu_dt_3', 'fu_dt_4', 'fu_dt_5']]

count_stuff=count_stuff.fillna('', axis=1)
#something=count_stuff.T
#column_list=something.columns.tolist()
#something=something.reset_index()
#column_list
#hope=pd.DataFrame()
#something.fillna("",inplace=True)
#for item in column_list:
    #test=something[item].apply(' '.join).reset_index()
new4=count_stuff['fu_dt_4']
new3=count_stuff['fu_dt_3']
new2=count_stuff['fu_dt_2']
new1=count_stuff['fu_dt_1']



count_stuff["combined_date"]= count_stuff['fu_dt_5']
count_stuff["combined_date"].fillna('',inplace=True)
count_stuff["combined_date"]=count_stuff["combined_date"].str.cat(new4, sep =", ")
count_stuff["combined_date"].fillna('',inplace=True)
count_stuff["combined_date"]=count_stuff["combined_date"].str.cat(new3, sep =", ")
count_stuff["combined_date"].fillna('',inplace=True)
count_stuff["combined_date"]=count_stuff["combined_date"].str.cat(new2, sep =", ")
count_stuff["combined_date"].fillna('',inplace=True)
count_stuff["combined_date"]=count_stuff["combined_date"].str.cat(new1, sep =", ")
condensed_data['combined_date']=count_stuff['combined_date']
condensed_data

contact4=condensed_data['fu_method_4']
contact3=condensed_data['fu_method_3']
contact2=condensed_data['fu_method_2']
contact1=condensed_data['fu_method_1']
condensed_data["contact"]=condensed_data['fu_method_5']
condensed_data["contact"].fillna('',inplace=True)
condensed_data["contact"]=condensed_data["contact"].str.cat(contact4, sep =" ")
condensed_data["contact"].fillna('',inplace=True)
condensed_data["contact"]=condensed_data["contact"].str.cat(contact3, sep =" ")
condensed_data["contact"].fillna('',inplace=True)
condensed_data["contact"]=condensed_data["contact"].str.cat(contact2, sep =" ")
condensed_data["contact"].fillna('',inplace=True)
condensed_data["contact"]=condensed_data["contact"].str.cat(contact1, sep =" ")
condensed_data["contact"].fillna('None',inplace=True)
condensed_data['contact']=condensed_data['contact']
condensed_data['contact']=condensed_data['contact'].str.extract('([^\s]+)')
condensed_data['last_contact_time']=condensed_data['combined_date'].str.extract('(..[:]..)')
#condensed_data['last_contact_time']=condensed_data['combined_date'].str.extract('([\d:]+$)')
condensed_data['last_contact_time']=condensed_data['last_contact_time'].fillna('0:00')
#count_stuff
condensed_data
# Out:
#                                                           study_id  sex  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0  0001b470ffdea9daf4e3e25a9cfb93d0  2.0
# 0003a8af34dd38929b6d0dff83a281e5  0003a8af34dd38929b6d0dff83a281e5  NaN
# 00042cd8cfa979e5cbf9aa79a01ec23d  00042cd8cfa979e5cbf9aa79a01ec23d  2.0
# 0014065de00658be8463cc209aae5bc1  0014065de00658be8463cc209aae5bc1  2.0
# 001e2c5b018d498cd8498e2b9d0ce0c7  001e2c5b018d498cd8498e2b9d0ce0c7  2.0
# ...                                                            ...  ...
# ffec65b7a5fd2d36cd56e0b249322d1f  ffec65b7a5fd2d36cd56e0b249322d1f  NaN
# ffeeb12c35a69dcdd34c4b2db6951789  ffeeb12c35a69dcdd34c4b2db6951789  2.0
# ffef6be3cbb0c80342dba653133169df  ffef6be3cbb0c80342dba653133169df  1.0
# fffdb5ffd34614801b0eb102ad4527bd  fffdb5ffd34614801b0eb102ad4527bd  1.0
# ffff49a8692e072fcb5df471ac7bd82a  ffff49a8692e072fcb5df471ac7bd82a  2.0
#
#                                   birthyear initial_date  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0     1980.0   2021-02-28
# 0003a8af34dd38929b6d0dff83a281e5        NaN   2019-10-16
# 00042cd8cfa979e5cbf9aa79a01ec23d     1947.0   2021-06-30
# 0014065de00658be8463cc209aae5bc1     1961.0   2020-01-17
# 001e2c5b018d498cd8498e2b9d0ce0c7     1958.0   2020-03-13
# ...                                     ...          ...
# ffec65b7a5fd2d36cd56e0b249322d1f     1970.0   2020-01-13
# ffeeb12c35a69dcdd34c4b2db6951789     1955.0   2019-09-22
# ffef6be3cbb0c80342dba653133169df     1933.0   2019-09-28
# fffdb5ffd34614801b0eb102ad4527bd     1981.0   2019-04-20
# ffff49a8692e072fcb5df471ac7bd82a     1972.0   2021-03-03
#
#                                  initial_contact_method           fu_dt_1  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0                  email    3/9/2021 15:26
# 0003a8af34dd38929b6d0dff83a281e5          self_referred  10/16/2019 15:11
# 00042cd8cfa979e5cbf9aa79a01ec23d                  email    7/8/2021 12:40
# 0014065de00658be8463cc209aae5bc1                  email   1/21/2020 17:50
# 001e2c5b018d498cd8498e2b9d0ce0c7                  email              None
# ...                                                 ...               ...
# ffec65b7a5fd2d36cd56e0b249322d1f              in_person    1/13/2020 9:54
# ffeeb12c35a69dcdd34c4b2db6951789                  email  10/21/2019 15:31
# ffef6be3cbb0c80342dba653133169df                  email              None
# fffdb5ffd34614801b0eb102ad4527bd                  email    4/26/2019 9:00
# ffff49a8692e072fcb5df471ac7bd82a                  email    3/5/2021 15:26
#
#                                  fu_method_1  fu_outcome_1           fu_dt_2  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0       phone          None    4/8/2022 14:38
# 0003a8af34dd38929b6d0dff83a281e5       phone          None              None
# 00042cd8cfa979e5cbf9aa79a01ec23d       phone  crc_followup    4/8/2022 12:25
# 0014065de00658be8463cc209aae5bc1       phone          None   2/24/2022 17:13
# 001e2c5b018d498cd8498e2b9d0ce0c7        None          None              None
# ...                                      ...           ...               ...
# ffec65b7a5fd2d36cd56e0b249322d1f       phone          None              None
# ffeeb12c35a69dcdd34c4b2db6951789          vm          None  10/23/2019 13:34
# ffef6be3cbb0c80342dba653133169df        None          None              None
# fffdb5ffd34614801b0eb102ad4527bd       phone          None              None
# ffff49a8692e072fcb5df471ac7bd82a       phone          None    3/4/2022 14:49
#
#                                  fu_method_2  ... coded_location  \
# study_id                                      ...
# 0001b470ffdea9daf4e3e25a9cfb93d0       phone  ...            1.0
# 0003a8af34dd38929b6d0dff83a281e5        None  ...            2.0
# 00042cd8cfa979e5cbf9aa79a01ec23d       phone  ...            1.0
# 0014065de00658be8463cc209aae5bc1       phone  ...            7.0
# 001e2c5b018d498cd8498e2b9d0ce0c7        None  ...            2.0
# ...                                      ...  ...            ...
# ffec65b7a5fd2d36cd56e0b249322d1f        None  ...            2.0
# ffeeb12c35a69dcdd34c4b2db6951789       phone  ...            5.0
# ffef6be3cbb0c80342dba653133169df        None  ...            7.0
# fffdb5ffd34614801b0eb102ad4527bd        None  ...            2.0
# ffff49a8692e072fcb5df471ac7bd82a          vm  ...            2.0
#
#                                         visit_outcome freq contact_count  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0              no_show    2             5
# 0003a8af34dd38929b6d0dff83a281e5            completed    1             1
# 00042cd8cfa979e5cbf9aa79a01ec23d              no_show    3             4
# 0014065de00658be8463cc209aae5bc1             canceled    3             5
# 001e2c5b018d498cd8498e2b9d0ce0c7          rescheduled    2             0
# ...                                               ...  ...           ...
# ffec65b7a5fd2d36cd56e0b249322d1f            completed    1             1
# ffeeb12c35a69dcdd34c4b2db6951789  reschedule_me_later    1             3
# ffef6be3cbb0c80342dba653133169df             canceled    1             0
# fffdb5ffd34614801b0eb102ad4527bd            completed    1             1
# ffff49a8692e072fcb5df471ac7bd82a  reschedule_me_later    1             3
#
#                                  time_of_visit_from_planned  year   age  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0                   417 days  2022    42
# 0003a8af34dd38929b6d0dff83a281e5                     6 days  2019  <NA>
# 00042cd8cfa979e5cbf9aa79a01ec23d                   302 days  2022    75
# 0014065de00658be8463cc209aae5bc1                   796 days  2022    61
# 001e2c5b018d498cd8498e2b9d0ce0c7                   997 days  2022    64
# ...                                                     ...   ...   ...
# ffec65b7a5fd2d36cd56e0b249322d1f                    16 days  2020    50
# ffeeb12c35a69dcdd34c4b2db6951789                    54 days  2019    64
# ffef6be3cbb0c80342dba653133169df                    10 days  2019    86
# fffdb5ffd34614801b0eb102ad4527bd                    11 days  2019    38
# ffff49a8692e072fcb5df471ac7bd82a                    16 days  2021    49
#
#                                                                       combined_date  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0  5/17/2022 14:56, 4/26/2022 15:46, 4/25/2022 12...
# 0003a8af34dd38929b6d0dff83a281e5                           , , , , 10/16/2019 15:11
# 00042cd8cfa979e5cbf9aa79a01ec23d  , 5/5/2022 16:17, 4/13/2022 11:40, 4/8/2022 12...
# 0014065de00658be8463cc209aae5bc1  3/22/2022 16:54, 3/16/2022 13:26, 2/25/2022 11...
# 001e2c5b018d498cd8498e2b9d0ce0c7                                           , , , ,
# ...                                                                             ...
# ffec65b7a5fd2d36cd56e0b249322d1f                             , , , , 1/13/2020 9:54
# ffeeb12c35a69dcdd34c4b2db6951789  , , 12/8/2021 17:44, 10/23/2019 13:34, 10/21/2...
# ffef6be3cbb0c80342dba653133169df                                           , , , ,
# fffdb5ffd34614801b0eb102ad4527bd                             , , , , 4/26/2019 9:00
# ffff49a8692e072fcb5df471ac7bd82a  , , 9/21/2022 17:21, 3/4/2022 14:49, 3/5/2021 ...
#
#                                  contact last_contact_time
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0   phone             14:56
# 0003a8af34dd38929b6d0dff83a281e5   phone             15:11
# 00042cd8cfa979e5cbf9aa79a01ec23d      vm             16:17
# 0014065de00658be8463cc209aae5bc1      vm             16:54
# 001e2c5b018d498cd8498e2b9d0ce0c7    None              0:00
# ...                                  ...               ...
# ffec65b7a5fd2d36cd56e0b249322d1f   phone              9:54
# ffeeb12c35a69dcdd34c4b2db6951789      vm             17:44
# ffef6be3cbb0c80342dba653133169df    None              0:00
# fffdb5ffd34614801b0eb102ad4527bd   phone              9:00
# ffff49a8692e072fcb5df471ac7bd82a   phone             17:21
#
# [9150 rows x 34 columns]

# %%
condensed_data['last_contact_time'] = pd.to_datetime(condensed_data['last_contact_time'], format= '%H:%M', exact=False).dt.time
condensed_data_droped=condensed_data.drop(['study_id','fu_dt_1', 'fu_method_1','fu_outcome_1','fu_dt_2', 'fu_method_2','fu_outcome_2','fu_dt_3', 'fu_method_3','fu_outcome_3','fu_dt_4', 'fu_method_4','fu_outcome_4','fu_dt_5', 'fu_method_5','fu_outcome_5','combined_date'], axis=1)
#condensed_data=condensed_data.drop('study_id', axis=0)
condensed_data_droped
# Out:
#                                   sex  birthyear initial_date  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0  2.0     1980.0   2021-02-28
# 0003a8af34dd38929b6d0dff83a281e5  NaN        NaN   2019-10-16
# 00042cd8cfa979e5cbf9aa79a01ec23d  2.0     1947.0   2021-06-30
# 0014065de00658be8463cc209aae5bc1  2.0     1961.0   2020-01-17
# 001e2c5b018d498cd8498e2b9d0ce0c7  2.0     1958.0   2020-03-13
# ...                               ...        ...          ...
# ffec65b7a5fd2d36cd56e0b249322d1f  NaN     1970.0   2020-01-13
# ffeeb12c35a69dcdd34c4b2db6951789  2.0     1955.0   2019-09-22
# ffef6be3cbb0c80342dba653133169df  1.0     1933.0   2019-09-28
# fffdb5ffd34614801b0eb102ad4527bd  1.0     1981.0   2019-04-20
# ffff49a8692e072fcb5df471ac7bd82a  2.0     1972.0   2021-03-03
#
#                                  initial_contact_method visit_planned_date  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0                  email           4/8/2022
# 0003a8af34dd38929b6d0dff83a281e5          self_referred         10/16/2019
# 00042cd8cfa979e5cbf9aa79a01ec23d                  email          4/20/2022
# 0014065de00658be8463cc209aae5bc1                  email          3/16/2022
# 001e2c5b018d498cd8498e2b9d0ce0c7                  email           8/1/2022
# ...                                                 ...                ...
# ffec65b7a5fd2d36cd56e0b249322d1f              in_person          1/13/2020
# ffeeb12c35a69dcdd34c4b2db6951789                  email         10/23/2019
# ffef6be3cbb0c80342dba653133169df                  email          10/7/2019
# fffdb5ffd34614801b0eb102ad4527bd                  email          4/26/2019
# ffff49a8692e072fcb5df471ac7bd82a                  email           3/5/2021
#
#                                  visit_reminder_date actual_visit_date  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0           4/20/2022        2022-04-21
# 0003a8af34dd38929b6d0dff83a281e5          10/21/2019        2019-10-22
# 00042cd8cfa979e5cbf9aa79a01ec23d           4/27/2022        2022-04-28
# 0014065de00658be8463cc209aae5bc1           3/21/2022        2022-03-23
# 001e2c5b018d498cd8498e2b9d0ce0c7           7/29/2022        2022-12-05
# ...                                              ...               ...
# ffec65b7a5fd2d36cd56e0b249322d1f           1/28/2020        2020-01-29
# ffeeb12c35a69dcdd34c4b2db6951789          11/14/2019        2019-11-15
# ffef6be3cbb0c80342dba653133169df           10/7/2019        2019-10-08
# fffdb5ffd34614801b0eb102ad4527bd           4/30/2019        2019-05-01
# ffff49a8692e072fcb5df471ac7bd82a           3/18/2021        2021-03-19
#
#                                  visit_weekday  coded_location  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0             R             1.0
# 0003a8af34dd38929b6d0dff83a281e5             T             2.0
# 00042cd8cfa979e5cbf9aa79a01ec23d             R             1.0
# 0014065de00658be8463cc209aae5bc1             W             7.0
# 001e2c5b018d498cd8498e2b9d0ce0c7             M             2.0
# ...                                        ...             ...
# ffec65b7a5fd2d36cd56e0b249322d1f             W             2.0
# ffeeb12c35a69dcdd34c4b2db6951789             F             5.0
# ffef6be3cbb0c80342dba653133169df             T             7.0
# fffdb5ffd34614801b0eb102ad4527bd             W             2.0
# ffff49a8692e072fcb5df471ac7bd82a             F             2.0
#
#                                         visit_outcome  freq  contact_count  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0              no_show     2              5
# 0003a8af34dd38929b6d0dff83a281e5            completed     1              1
# 00042cd8cfa979e5cbf9aa79a01ec23d              no_show     3              4
# 0014065de00658be8463cc209aae5bc1             canceled     3              5
# 001e2c5b018d498cd8498e2b9d0ce0c7          rescheduled     2              0
# ...                                               ...   ...            ...
# ffec65b7a5fd2d36cd56e0b249322d1f            completed     1              1
# ffeeb12c35a69dcdd34c4b2db6951789  reschedule_me_later     1              3
# ffef6be3cbb0c80342dba653133169df             canceled     1              0
# fffdb5ffd34614801b0eb102ad4527bd            completed     1              1
# ffff49a8692e072fcb5df471ac7bd82a  reschedule_me_later     1              3
#
#                                  time_of_visit_from_planned  year   age  \
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0                   417 days  2022    42
# 0003a8af34dd38929b6d0dff83a281e5                     6 days  2019  <NA>
# 00042cd8cfa979e5cbf9aa79a01ec23d                   302 days  2022    75
# 0014065de00658be8463cc209aae5bc1                   796 days  2022    61
# 001e2c5b018d498cd8498e2b9d0ce0c7                   997 days  2022    64
# ...                                                     ...   ...   ...
# ffec65b7a5fd2d36cd56e0b249322d1f                    16 days  2020    50
# ffeeb12c35a69dcdd34c4b2db6951789                    54 days  2019    64
# ffef6be3cbb0c80342dba653133169df                    10 days  2019    86
# fffdb5ffd34614801b0eb102ad4527bd                    11 days  2019    38
# ffff49a8692e072fcb5df471ac7bd82a                    16 days  2021    49
#
#                                  contact last_contact_time
# study_id
# 0001b470ffdea9daf4e3e25a9cfb93d0   phone          14:56:00
# 0003a8af34dd38929b6d0dff83a281e5   phone          15:11:00
# 00042cd8cfa979e5cbf9aa79a01ec23d      vm          16:17:00
# 0014065de00658be8463cc209aae5bc1      vm          16:54:00
# 001e2c5b018d498cd8498e2b9d0ce0c7    None          00:00:00
# ...                                  ...               ...
# ffec65b7a5fd2d36cd56e0b249322d1f   phone          09:54:00
# ffeeb12c35a69dcdd34c4b2db6951789      vm          17:44:00
# ffef6be3cbb0c80342dba653133169df    None          00:00:00
# fffdb5ffd34614801b0eb102ad4527bd   phone          09:00:00
# ffff49a8692e072fcb5df471ac7bd82a   phone          17:21:00
#
# [9150 rows x 17 columns]

# %%
### Machine learning model we will be using Data currently wont quite fit into this but we are working on that just need to encode the data
# Create our features and target
X = condensed_data.drop(columns="visit_outcome")

y = condensed_data["visit_outcome"]

# %%
### spliting our training data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape

# %%
### resapling pur data and making our predictions
rf_model = RandomForestClassifier(n_estimators=128, random_state=1) 
rf_model = rf_model.fit(X_train, y_train)
predictions = rf_model.predict(X_test)

# %%
### our balanced accuracy score
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(y_test, predictions)

# %%
### Our confustion matrix
from sklearn.metrics import confusion_matrix


confusion_matrix(y_test, predictions)

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, predictions))

# %%
# List the features sorted in descending order by feature importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)

# %%
condensed_data.dtypes
# Out:
# study_id                          object
# sex                              float64
# birthyear                        float64
# initial_date                      object
# initial_contact_method            object
# fu_dt_1                           object
# fu_method_1                       object
# fu_outcome_1                      object
# fu_dt_2                           object
# fu_method_2                       object
# fu_outcome_2                      object
# fu_dt_3                           object
# fu_method_3                       object
# fu_outcome_3                      object
# fu_dt_4                           object
# fu_method_4                       object
# fu_outcome_4                      object
# fu_dt_5                           object
# fu_method_5                       object
# fu_outcome_5                      object
# visit_planned_date                object
# visit_reminder_date               object
# actual_visit_date         datetime64[ns]
# visit_weekday                     object
# coded_location                   float64
# visit_outcome                     object
# freq                               int64
# contact_count                      int64
# year                               int64
# age                                Int16
# date_time_fu_dt_2         datetime64[ns]
# date_fu_dt_2                      object
# time_fu_dt_2                      object
# dtype: object

# %%
condensed_data.to_csv('test1.csv')
